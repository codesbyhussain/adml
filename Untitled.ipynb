# %%
from PIL import Image
from pathlib import Path

data_dir = Path("data/processed/images/train")
for img_path in data_dir.glob("*.tif"):
    img = Image.open(img_path)
    print(img_path.name, img.width, img.height)
# Out:
# 10cm_train_1.tif 1024 1024
# 10cm_train_10.tif 1024 1024
# 10cm_train_11.tif 1024 1024
# 10cm_train_12.tif 1024 1024
# 10cm_train_13.tif 1024 1024
# 10cm_train_14.tif 1024 1024
# 10cm_train_15.tif 1024 1024
# 10cm_train_16.tif 1024 1024
# 10cm_train_17.tif 1024 1024
# 10cm_train_18.tif 1024 1024
# 10cm_train_2.tif 1024 1024
# 10cm_train_21.tif 1024 1024
# 10cm_train_22.tif 1024 1024
# 10cm_train_23.tif 1024 1024
# 10cm_train_24.tif 1024 1024
# 10cm_train_25.tif 1024 1024
# 10cm_train_27.tif 1024 1024
# 10cm_train_28.tif 1024 1024
# 10cm_train_29.tif 1024 1024
# 10cm_train_3.tif 1024 1024
# 10cm_train_30.tif 1024 1024
# 10cm_train_33.tif 1024 1024
# 10cm_train_34.tif 1024 1024
# 10cm_train_35.tif 1024 1024
# 10cm_train_36.tif 1024 1024
# 10cm_train_37.tif 1024 1024
# 10cm_train_4.tif 1024 1024
# 10cm_train_5.tif 1024 1024
# 10cm_train_6.tif 1024 1024
# 10cm_train_7.tif 1024 1024
# 10cm_train_9.tif 1024 1024
# 20cm_train_39.tif 1024 1024
# 20cm_train_40.tif 1024 1024
# ...

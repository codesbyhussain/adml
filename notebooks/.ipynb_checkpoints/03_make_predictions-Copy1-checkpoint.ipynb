# %% [markdown]
# # Make Predictions on Training Data

# %%
# Import Packages
import ultralytics
from ultralytics import YOLO
import numpy as np
import time
import yaml
from pathlib import Path
import torch
import pandas as pd
from shutil import copy2

#-- Directories and Paths --#
REPO_ROOT = Path("..")      

DATA_CONFIG_PATH = REPO_ROOT / 'configurations' / 'model_data-seg.yaml'

#-- Model --#

# Load model parameters / overrides
with open(REPO_ROOT / 'configurations' / 'val_model_overrides.yaml', 'r') as f:
    overrides = yaml.safe_load(f)

# Override path in your dictionary
overrides['data'] = str(DATA_CONFIG_PATH)

# Assign Trained Model Weights
def resolve(p: str | Path) -> Path:
    p = Path(p)
    return p if p.is_absolute() else (REPO_ROOT / p)

weights_path = resolve(overrides.pop("weights"))

# Load Trained Model's Weights
model = YOLO(str(weights_path))  

# Predictions from the model
with torch.inference_mode():
    metrics = model.val(**overrides)


#-- Results --#

#--- Results Directory ---#
# where YOLO saved this run
out_dir = Path(metrics.save_dir)
out_dir.mkdir(parents=True, exist_ok=True)

#--- Precision & Recall Calculations ---#

# names -> {id: name}; confusion matrix includes a last row/col for "background"
names = [metrics.names[i] for i in range(len(metrics.names))]
cm = metrics.confusion_matrix.matrix.astype(np.int64)   # shape = (nc+1, nc+1) # cm = confusion_matrix
nc = len(names) # nc = name classes

# diagonal (exclude background) = TP
tp = np.diag(cm)[:nc]

# row sums (include background col) minus TP = FP for that predicted class
fp = cm[:nc, :].sum(axis=1) - tp

# column sums (include background row) minus TP = FN for that true class
fn = cm[:, :nc].sum(axis=0) - tp

precision = tp / (tp + fp + 1e-16)
recall    = tp / (tp + fn + 1e-16)
f1        = 2 * precision * recall / (precision + recall + 1e-16)

df = pd.DataFrame({
    "class": names, "TP": tp, "FP": fp, "FN": fn,
    "precision": precision, "recall": recall, "f1": f1
})
print(df)
# Output P&R Results
df.to_csv(out_dir / "P&R_results.csv", header=True,index=True)   
print(f"Saved df results metrics to {out_dir/'df_results.csv'}")


#-- Export Validation Results --#
# dataframe
validation_df = metrics.to_df()

# validation_df.to_csv(csv_path, header=True, index=True)
summary_df = pd.DataFrame([metrics.results_dict])  # <-- dict -> one-row DataFrame
summary_df.to_csv(out_dir / "summary_metrics_results.csv", index=False)
print(f"Saved metrics to {out_dir/'results.csv'}")




# choose task: 'seg' for masks, 'box' for boxes
task = 'seg' # Choosing specific 'task' type of 'segmentation' selects for metric associates
seg_metrics = getattr(metrics, task)

print(f"AP@0.75 ({task}): {seg_metrics.map75:.4f}")
print(f"AP@0.50 ({task}): {seg_metrics.map50:.4f}")
print(f"Classes  mAP@0.50:0.95 ({task}): {seg_metrics.map:.4f}")

# Per-class mAP (COCO mAP@0.50:0.95) if exposed
names = metrics.names if isinstance(metrics.names, (list, tuple)) else list(metrics.names.values())
if hasattr(seg_metrics, "maps") and seg_metrics.maps is not None:
    for i, name in enumerate(names):
        print(f"{name:>16}  mAP@0.50:0.95 = {seg_metrics.maps[i]:.4f}")


# Copy test_parameters into output folder
test_model_overrides = Path(REPO_ROOT / 'configurations/val_model_overrides.yaml')
copy2(test_model_overrides, metrics.save_dir / test_model_overrides.name )
try:
    print(f'"val_model_parameters" Copied to : {metrics.save_dir}')
except Exception:
    print('Error - Parameters Not Copied To Output')

# State output location
try:
    print("Output Metrics Saved to:", metrics.save_dir)
except Exception:
    print('Error - Location Not Printed')
# Out:
# Ultralytics 8.3.185  Python-3.11.14 torch-2.5.1 CPU (Intel Xeon Gold 6230R CPU @ 2.10GHz)
# YOLO11s-seg summary (fused): 113 layers, 10,067,590 parameters, 0 gradients, 32.8 GFLOPs
# val: Fast image access  (ping: 0.00.0 ms, read: 1593.482.8 MB/s, size: 3072.3 KB)
# val: Scanning C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\labels\val.cache... 30 images, 0 bac
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP
# requirements: Ultralytics requirement ['faster-coco-eval>=1.6.7'] not found, attempting AutoUpdate...
# Collecting faster-coco-eval>=1.6.7
#   Downloading faster_coco_eval-1.7.0-cp311-cp311-win_amd64.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in c:\users\hmanasi1\.conda\envs\gpu\lib\site-packages (from faster-coco-eval>=1.6.7) (2.0.1)
# Downloading faster_coco_eval-1.7.0-cp311-cp311-win_amd64.whl (319 kB)
# Installing collected packages: faster-coco-eval
# Successfully installed faster-coco-eval-1.7.0
#
# requirements: AutoUpdate success  6.0s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
# WARNING Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP
# WARNING Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP
# WARNING Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP
#                    all         30       7960       0.64      0.207      0.429      0.248       0.67      0.209      0.443      0.218
#        individual_tree         30       7104      0.695      0.347       0.53      0.302      0.684      0.341      0.521       0.25
#         group_of_trees         26        856      0.586     0.0678      0.329      0.193      0.657     0.0759      0.365      0.185
# Speed: 9.0ms preprocess, 243.8ms inference, 0.0ms loss, 430.3ms postprocess per image
# Saving runs\segment\val_Yolo11s_canopy_832_adamW_5\predictions.json...
# Results saved to runs\segment\val_Yolo11s_canopy_832_adamW_5
#              class    TP   FP    FN  precision    recall        f1
# 0  individual_tree  2550  998  4554   0.718715  0.358953  0.478783
# 1   group_of_trees    64   35   792   0.646465  0.074766  0.134031
# Saved df results metrics to runs\segment\val_Yolo11s_canopy_832_adamW_5\df_results.csv
# Saved metrics to runs\segment\val_Yolo11s_canopy_832_adamW_5\results.csv
# AP@0.75 (seg): 0.1936
# AP@0.50 (seg): 0.4430
# Classes  mAP@0.50:0.95 (seg): 0.2175
#  individual_tree  mAP@0.50:0.95 = 0.2500
#   group_of_trees  mAP@0.50:0.95 = 0.1850
# "val_model_parameters" Copied to : runs\segment\val_Yolo11s_canopy_832_adamW_5
# Output Metrics Saved to: runs\segment\val_Yolo11s_canopy_832_adamW_5

# %% [markdown]
# # Make Prediction On Evaluation Data

# %%
import ultralytics
from ultralytics import YOLO
import numpy as np
import time
import yaml
from pathlib import Path
import torch
from datetime import datetime

current_dt = datetime.now().strftime('%Y-%m-%d')
REPO_ROOT = Path("..")   

# Load model parameters / overrides YAML
with open(REPO_ROOT / 'configurations' / 'predict_model_overrides.yaml', 'r') as f: # Modify overrides where necessary
    overrides = yaml.safe_load(f)

# Make YAML Paths Absolute
for key in ("source", "project"):
    if key in overrides:
        overrides[key] = str((REPO_ROOT / overrides[key]).resolve())

# Load Trained Model Weights
def resolve(p: str | Path) -> Path:
    p = Path(p)
    return p if p.is_absolute() else (REPO_ROOT / p)

weights_path = resolve(overrides.pop("weights"))

# Model Naming
# optional: use the training run name from the weights path
train_run = weights_path.parents[1].name  # e.g., train_Yolov8s_canopy_832_...
run_name = f"predict_{train_run}_{current_dt}"

# inject name (and project if you want a different subfolder)
overrides.setdefault("project", str(REPO_ROOT / "runs"))
overrides["name"] = run_name
# overrides["exist_ok"] = True  # set True to overwrite instead of auto-appending _2

# Load Trained Model's Weights
model = YOLO(str(weights_path))  

# Predictions from the model
with torch.inference_mode():
    predictions = model.predict(**overrides)

# State output location

# Stream = True
for last in predictions:
    pass
print("Saved to:", last.save_dir)

# Stream = False
# print("Outputs saved to:", predictions[0].save_dir)
# Out:
# image 1/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_1.tif: 1024x1024 53 individual_trees, 344.3ms
# image 2/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_10.tif: 1024x1024 63 individual_trees, 3 group_of_treess, 236.4ms
# image 3/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_11.tif: 1024x1024 229 individual_trees, 3 group_of_treess, 261.2ms
# image 4/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_12.tif: 1024x1024 77 individual_trees, 7 group_of_treess, 249.8ms
# image 5/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_13.tif: 1024x1024 165 individual_trees, 335.4ms
# image 6/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_14.tif: 1024x1024 90 individual_trees, 224.0ms
# image 7/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_15.tif: 1024x1024 108 individual_trees, 313.5ms
# image 8/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_16.tif: 1024x1024 112 individual_trees, 1 group_of_trees, 279.6ms
# image 9/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_17.tif: 1024x1024 142 individual_trees, 13 group_of_treess, 281.5ms
# image 10/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_18.tif: 1024x1024 115 individual_trees, 5 group_of_treess, 293.4ms
# image 11/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_19.tif: 1024x1024 167 individual_trees, 288.8ms
# image 12/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_2.tif: 1024x1024 69 individual_trees, 1 group_of_trees, 337.8ms
# image 13/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_20.tif: 1024x1024 163 individual_trees, 250.5ms
# image 14/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_21.tif: 1024x1024 148 individual_trees, 275.9ms
# image 15/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_22.tif: 1024x1024 170 individual_trees, 1 group_of_trees, 224.6ms
# image 16/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_23.tif: 1024x1024 187 individual_trees, 309.2ms
# image 17/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_24.tif: 1024x1024 149 individual_trees, 305.3ms
# image 18/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_25.tif: 1024x1024 160 individual_trees, 235.8ms
# image 19/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_26.tif: 1024x1024 36 individual_trees, 321.7ms
# image 20/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_27.tif: 1024x1024 300 individual_trees, 237.5ms
# image 21/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_28.tif: 1024x1024 186 individual_trees, 4 group_of_treess, 247.3ms
# image 22/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_29.tif: 1024x1024 93 individual_trees, 5 group_of_treess, 194.0ms
# image 23/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_3.tif: 1024x1024 16 individual_trees, 2 group_of_treess, 355.9ms
# image 24/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_30.tif: 1024x1024 197 individual_trees, 5 group_of_treess, 256.2ms
# image 25/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_31.tif: 1024x1024 144 individual_trees, 3 group_of_treess, 231.6ms
# image 26/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_32.tif: 1024x1024 272 individual_trees, 7 group_of_treess, 322.6ms
# image 27/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_33.tif: 1024x1024 103 individual_trees, 1 group_of_trees, 261.1ms
# image 28/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_34.tif: 1024x1024 209 individual_trees, 2 group_of_treess, 247.3ms
# image 29/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_35.tif: 1024x1024 67 individual_trees, 259.4ms
# image 30/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_36.tif: 1024x1024 98 individual_trees, 316.3ms
# image 31/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_37.tif: 1024x1024 101 individual_trees, 232.9ms
# image 32/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_38.tif: 1024x1024 300 individual_trees, 283.0ms
# image 33/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_4.tif: 1024x1024 110 individual_trees, 5 group_of_treess, 287.3ms
# image 34/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_5.tif: 1024x1024 16 individual_trees, 4 group_of_treess, 332.8ms
# image 35/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_6.tif: 1024x1024 34 individual_trees, 7 group_of_treess, 275.9ms
# image 36/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_7.tif: 1024x1024 300 individual_trees, 228.0ms
# image 37/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_8.tif: 1024x1024 24 individual_trees, 3 group_of_treess, 263.7ms
# image 38/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_9.tif: 1024x1024 43 individual_trees, 7 group_of_treess, 234.4ms
# image 39/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_39.tif: 1024x1024 273 individual_trees, 7 group_of_treess, 261.2ms
# image 40/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_40.tif: 1024x1024 236 individual_trees, 4 group_of_treess, 292.5ms
# image 41/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_41.tif: 1024x1024 240 individual_trees, 2 group_of_treess, 219.6ms
# image 42/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_42.tif: 1024x1024 135 individual_trees, 2 group_of_treess, 349.7ms
# image 43/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_43.tif: 1024x1024 298 individual_trees, 2 group_of_treess, 338.2ms
# image 44/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_44.tif: 1024x1024 153 individual_trees, 2 group_of_treess, 282.7ms
# image 45/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_45.tif: 1024x1024 148 individual_trees, 8 group_of_treess, 340.2ms
# image 46/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_46.tif: 1024x1024 130 individual_trees, 1 group_of_trees, 248.0ms
# image 47/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_47.tif: 1024x1024 144 individual_trees, 6 group_of_treess, 309.1ms
# image 48/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_48.tif: 1024x1024 135 individual_trees, 7 group_of_treess, 266.1ms
# image 49/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_49.tif: 1024x1024 248 individual_trees, 8 group_of_treess, 312.2ms
# image 50/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_50.tif: 1024x1024 100 individual_trees, 2 group_of_treess, 281.8ms
# image 51/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_51.tif: 1024x1024 93 individual_trees, 3 group_of_treess, 216.9ms
# image 52/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_52.tif: 1024x1024 296 individual_trees, 4 group_of_treess, 280.0ms
# image 53/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_53.tif: 1024x1024 95 individual_trees, 2 group_of_treess, 280.0ms
# image 54/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_54.tif: 1024x1024 131 individual_trees, 3 group_of_treess, 240.1ms
# image 55/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_55.tif: 1024x1024 157 individual_trees, 7 group_of_treess, 288.5ms
# image 56/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_56.tif: 1024x1024 298 individual_trees, 2 group_of_treess, 337.5ms
# image 57/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_57.tif: 1024x1024 113 individual_trees, 1 group_of_trees, 237.3ms
# image 58/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_58.tif: 1024x1024 104 individual_trees, 265.9ms
# image 59/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_59.tif: 1024x1024 115 individual_trees, 218.1ms
# image 60/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_60.tif: 1024x1024 109 individual_trees, 2 group_of_treess, 270.3ms
# image 61/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_61.tif: 1024x1024 68 individual_trees, 5 group_of_treess, 309.0ms
# image 62/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_62.tif: 1024x1024 136 individual_trees, 259.4ms
# image 63/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_63.tif: 1024x1024 277 individual_trees, 7 group_of_treess, 267.2ms
# image 64/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_64.tif: 1024x1024 42 individual_trees, 7 group_of_treess, 297.8ms
# image 65/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_65.tif: 1024x1024 138 individual_trees, 338.1ms
# image 66/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_66.tif: 1024x1024 71 individual_trees, 2 group_of_treess, 241.6ms
# image 67/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_67.tif: 1024x1024 264 individual_trees, 8 group_of_treess, 290.1ms
# image 68/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_68.tif: 1024x1024 119 individual_trees, 221.0ms
# image 69/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_69.tif: 1024x1024 137 individual_trees, 231.1ms
# image 70/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_70.tif: 1024x1024 278 individual_trees, 2 group_of_treess, 266.0ms
# image 71/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_71.tif: 1024x1024 111 individual_trees, 5 group_of_treess, 264.2ms
# image 72/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_72.tif: 1024x1024 299 individual_trees, 1 group_of_trees, 307.0ms
# image 73/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_73.tif: 1024x1024 297 individual_trees, 3 group_of_treess, 270.6ms
# image 74/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_74.tif: 1024x1024 99 individual_trees, 5 group_of_treess, 215.2ms
# image 75/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_75.tif: 1024x1024 90 individual_trees, 2 group_of_treess, 200.9ms
# image 76/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_100.tif: 1024x1024 269 individual_trees, 251.8ms
# image 77/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_76.tif: 1024x1024 67 individual_trees, 248.1ms
# image 78/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_77.tif: 1024x1024 168 individual_trees, 10 group_of_treess, 193.5ms
# image 79/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_78.tif: 1024x1024 278 individual_trees, 19 group_of_treess, 202.4ms
# image 80/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_79.tif: 1024x1024 288 individual_trees, 12 group_of_treess, 298.1ms
# image 81/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_80.tif: 1024x1024 275 individual_trees, 25 group_of_treess, 248.5ms
# image 82/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_81.tif: 1024x1024 181 individual_trees, 18 group_of_treess, 224.1ms
# image 83/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_82.tif: 1024x1024 105 individual_trees, 12 group_of_treess, 330.0ms
# image 84/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_83.tif: 1024x1024 212 individual_trees, 7 group_of_treess, 348.3ms
# image 85/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_84.tif: 1024x1024 111 individual_trees, 12 group_of_treess, 300.3ms
# image 86/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_85.tif: 1024x1024 67 individual_trees, 4 group_of_treess, 318.5ms
# image 87/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_86.tif: 1024x1024 209 individual_trees, 6 group_of_treess, 287.2ms
# image 88/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_87.tif: 1024x1024 261 individual_trees, 39 group_of_treess, 216.1ms
# image 89/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_88.tif: 1024x1024 288 individual_trees, 12 group_of_treess, 334.9ms
# image 90/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_89.tif: 1024x1024 296 individual_trees, 4 group_of_treess, 225.4ms
# image 91/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_90.tif: 1024x1024 293 individual_trees, 7 group_of_treess, 215.0ms
# image 92/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_91.tif: 1024x1024 285 individual_trees, 15 group_of_treess, 308.9ms
# image 93/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_92.tif: 1024x1024 286 individual_trees, 14 group_of_treess, 206.3ms
# image 94/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_93.tif: 1024x1024 285 individual_trees, 15 group_of_treess, 338.4ms
# image 95/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_94.tif: 1024x1024 298 individual_trees, 2 group_of_treess, 315.3ms
# image 96/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_95.tif: 1024x1024 180 individual_trees, 26 group_of_treess, 202.9ms
# image 97/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_96.tif: 1024x1024 187 individual_trees, 3 group_of_treess, 335.3ms
# image 98/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_97.tif: 1024x1024 87 individual_trees, 306.8ms
# image 99/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_98.tif: 1024x1024 298 individual_trees, 2 group_of_treess, 289.2ms
# image 100/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_99.tif: 1024x1024 298 individual_trees, 2 group_of_treess, 273.2ms
# image 101/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_101.tif: 1024x1024 271 individual_trees, 25 group_of_treess, 339.5ms
# image 102/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_102.tif: 1024x1024 286 individual_trees, 14 group_of_treess, 392.6ms
# image 103/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_103.tif: 1024x1024 256 individual_trees, 44 group_of_treess, 322.0ms
# image 104/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_104.tif: 1024x1024 280 individual_trees, 20 group_of_treess, 342.0ms
# image 105/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_105.tif: 1024x1024 259 individual_trees, 41 group_of_treess, 227.8ms
# image 106/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_106.tif: 1024x1024 245 individual_trees, 55 group_of_treess, 348.2ms
# image 107/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_107.tif: 1024x1024 295 individual_trees, 5 group_of_treess, 344.9ms
# image 108/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_108.tif: 1024x1024 277 individual_trees, 23 group_of_treess, 224.8ms
# image 109/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_109.tif: 1024x1024 292 individual_trees, 8 group_of_treess, 236.9ms
# image 110/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_110.tif: 1024x1024 297 individual_trees, 3 group_of_treess, 223.8ms
# image 111/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_111.tif: 1024x1024 262 individual_trees, 38 group_of_treess, 247.9ms
# image 112/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_112.tif: 1024x1024 270 individual_trees, 30 group_of_treess, 349.7ms
# image 113/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_113.tif: 1024x1024 265 individual_trees, 35 group_of_treess, 242.6ms
# image 114/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_114.tif: 1024x1024 287 individual_trees, 13 group_of_treess, 215.3ms
# image 115/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_115.tif: 1024x1024 141 individual_trees, 18 group_of_treess, 354.0ms
# image 116/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_116.tif: 1024x1024 196 individual_trees, 36 group_of_treess, 215.7ms
# image 117/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_117.tif: 1024x1024 258 individual_trees, 39 group_of_treess, 240.5ms
# image 118/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_118.tif: 1024x1024 197 individual_trees, 103 group_of_treess, 339.0ms
# image 119/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_119.tif: 1024x1024 258 individual_trees, 42 group_of_treess, 224.3ms
# image 120/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_120.tif: 1024x1024 294 individual_trees, 6 group_of_treess, 249.3ms
# image 121/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_121.tif: 1024x1024 279 individual_trees, 21 group_of_treess, 235.4ms
# image 122/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_122.tif: 1024x1024 251 individual_trees, 49 group_of_treess, 216.0ms
# image 123/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_123.tif: 1024x1024 299 individual_trees, 1 group_of_trees, 214.5ms
# image 124/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_124.tif: 1024x1024 276 individual_trees, 24 group_of_treess, 328.6ms
# image 125/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_125.tif: 1024x1024 299 individual_trees, 1 group_of_trees, 219.0ms
# image 126/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_126.tif: 1024x1024 273 individual_trees, 27 group_of_treess, 243.3ms
# image 127/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_127.tif: 1024x1024 287 individual_trees, 13 group_of_treess, 231.5ms
# image 128/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_128.tif: 1024x1024 288 individual_trees, 12 group_of_treess, 338.4ms
# image 129/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_129.tif: 1024x1024 278 individual_trees, 22 group_of_treess, 338.3ms
# image 130/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_130.tif: 1024x1024 286 individual_trees, 14 group_of_treess, 213.6ms
# image 131/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_131.tif: 1024x1024 285 individual_trees, 15 group_of_treess, 220.1ms
# image 132/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_132.tif: 1024x1024 284 individual_trees, 16 group_of_treess, 213.7ms
# image 133/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_133.tif: 1024x1024 278 individual_trees, 22 group_of_treess, 248.5ms
# image 134/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_134.tif: 1024x1024 232 individual_trees, 68 group_of_treess, 343.1ms
# image 135/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_135.tif: 1024x1024 278 individual_trees, 21 group_of_treess, 221.6ms
# image 136/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_136.tif: 1024x1024 267 individual_trees, 31 group_of_treess, 232.3ms
# image 137/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_137.tif: 1024x1024 243 individual_trees, 56 group_of_treess, 316.8ms
# image 138/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_138.tif: 1024x1024 252 individual_trees, 48 group_of_treess, 225.7ms
# image 139/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_139.tif: 1024x1024 289 individual_trees, 11 group_of_treess, 316.7ms
# image 140/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_140.tif: 1024x1024 284 individual_trees, 15 group_of_treess, 366.4ms
# image 141/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_141.tif: 1024x1024 279 individual_trees, 21 group_of_treess, 216.7ms
# image 142/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_142.tif: 1024x1024 287 individual_trees, 8 group_of_treess, 229.3ms
# image 143/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_143.tif: 1024x1024 281 individual_trees, 19 group_of_treess, 222.6ms
# image 144/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_144.tif: 1024x1024 267 individual_trees, 33 group_of_treess, 331.5ms
# image 145/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_145.tif: 1024x1024 290 individual_trees, 10 group_of_treess, 313.4ms
# image 146/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_146.tif: 1024x1024 251 individual_trees, 49 group_of_treess, 229.3ms
# image 147/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_147.tif: 1024x1024 273 individual_trees, 27 group_of_treess, 219.8ms
# image 148/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_148.tif: 1024x1024 270 individual_trees, 30 group_of_treess, 226.6ms
# image 149/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_149.tif: 1024x1024 286 individual_trees, 14 group_of_treess, 326.7ms
# image 150/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_150.tif: 1024x1024 264 individual_trees, 36 group_of_treess, 356.0ms
# Speed: 48.8ms preprocess, 273.4ms inference, 510.1ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\runs\segment\predict_train_Yolo11s_canopy_832_adamW__2025-11-02
# 150 labels saved to C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\runs\segment\predict_train_Yolo11s_canopy_832_adamW__2025-11-02\labels
# Saved to: C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\runs\segment\predict_train_Yolo11s_canopy_832_adamW__2025-11-02

# %%
# Packages
from pathlib import Path
import pandas as pd
import numpy as np
import json
from PIL import Image
import pandas as pd
from datetime import datetime

# Create paths
REPO_ROOT = Path.cwd()

CURRENT_DATETIME = datetime.now().strftime('%Y-%m-%d')

# Prediction Annotations
labels = "../runs/segment/predict_train_Yolo11s_canopy_832_adamW__2025-11-02\labels" # Modify Prediction Txt annotations where necessary
IMGS = '../data/processed/images/predict'
OUT_JSON = REPO_ROOT / 'exports'/ str(CURRENT_DATETIME) / 'submission.json'



#---Define Functions---#

# Image Metadata
def get_meta(IMGS):

    meta_data = {}
    scene_type_default = "Unknown"
    IMGS = Path(IMGS)

    if IMGS.exists():

        for p in Path(IMGS).iterdir():
            if p.suffix.lower() not in {".tif"}: # All images .tif
                continue
            file_name = p.name
            cm_resolution = str(file_name[0:2])

            with Image.open(p) as image: # Pillow / Pill package
                width, height = image.size

            meta_data[file_name] = {
                'file_name' : file_name,
                "width" : width,
                'height' : height,
                "cm_resolution" : cm_resolution,
                "scene_type" : scene_type_default

            }
    else:
      print('Error - IMGs Not Exist')
    return meta_data

# Get Annotations
def get_annotations(LABELS):
    annotations = []

    for txt_file in sorted(Path(LABELS).iterdir()):
        
        if txt_file.is_file() and txt_file.suffix.lower() == ".txt":
            image_name = txt_file.name

            with open(txt_file, 'r') as file:
                for line in file:

                    # 1. Split the line into tokens
                    tokens = line.strip().split()

                    # 2. Convert tokens into usable pieces
                    class_id = int(tokens[0])                    # first token
                    *coords, confidence_level = map(float, tokens[1:])  
                    # all middle tokens are coords, last one is confidence
                    

                    # 3. Group coords into pairs (x,y)
                    segmentation = [
                        (coords[i], coords[i+1])
                        for i in range(0, len(coords), 2)
                    ]

                    # 4. Save everything into dict
                    annotations.append({
                        "image": image_name,
                        "class": class_id,
                        "confidence_level": confidence_level,
                        "segmentation": segmentation
                    })

    return annotations


# Denormalise segmentations to pixels

def denorm_segmentation(seg, width, height, *, flatten=True, round_int=True):
    """
    seg: list of (x,y) pairs in [0,1]
    returns: flat pixel list [x1,y1,x2,y2,...] (default) or list of pairs
    """
    # If seg is already flat [x1,y1,...], turn into pairs
    if seg and not isinstance(seg[0], (list, tuple)):
        it = iter(seg)
        seg_pairs = list(zip(it, it))
    else:
        seg_pairs = seg

    out = []
    for x, y in seg_pairs:
        X = max(0.0, min(width  - 1, x * width))
        Y = max(0.0, min(height - 1, y * height))
        if round_int:
            X = int(round(X))
            Y = int(round(Y))
        if flatten:
            out.extend([X, Y])
        else:
            out.append((X, Y))
    return out


# Append annotations to images

def append_imgs_annotations(img_list, annot_list):
    # ensure each image has an annotations list
    for img in img_list:
        if "annotations" not in img or img["annotations"] is None:
            img["annotations"] = []

    for image in img_list:
        w, h = image["width"], image["height"]
        fname = image["file_name"]

        # all annots for this image
        matched = (a for a in annot_list if a["image"] == fname)

        for a in matched:
            seg_px = denorm_segmentation(a["segmentation"], w, h, flatten=True, round_int=True) # Denormalise Segemetation to Pixels

            image["annotations"].append({
                "class": a["class"],
                "confidence_score": float(a["confidence_level"]),  # or keep as formatted string if you prefer
                "segmentation": seg_px
            })

    return img_list


# class id
ID_to_Name = {
    0 : 'individual_tree',
    1 : 'group_of_trees'
}



#--Procedure--#
print('Get Meta Data')
meta = get_meta(IMGS) # Retrieve Meta Data
meta_2items = list(meta.items())[:1]
meta_2keys = list(meta)[:1]

print(f'Meta Data Items : {meta_2items}')

print(f'Meta Data Keys : {meta_2items}')


images = [] # Produce Images list

print('Append Meta Data To Images List')
for m in meta.values(): # Append Meta Data to Images List
    images.append({
        'file_name' : m['file_name'],
        'width' : m['width'],
        'height' : m['height'],
        'cm_resolution' : m['cm_resolution'],
        'scene_type' : m['scene_type'],
        'annotations' : []
    })
    

images_sorted = sorted(images, key=lambda x: x['file_name']) # Sort Images
print(f'images_sorted ')
    
print('Get Annotations')
annotations_list = get_annotations(labels) # Retrieve Annotations & Denormalise Segmentations to Pixels

for annot in annotations_list: # Clean Annotations
    # .txt suffix -> .tif
    annot['image'] = annot['image'][:-4] + '.tif'

    # map class id -> name
    annot['class'] = ID_to_Name.get(annot['class'], 'Unknown')

    # convert confidence_level -> percentage string
    annot['confidence_level'] = f"{annot['confidence_level']:.2f}"

if annotations_list and len(annotations_list[0]) > 0:
    print('Annotations List Completed')

appended_list = append_imgs_annotations(images_sorted, annotations_list) # Append Annotations to Images

print(f'Appended_list Outputed ')

predict_answer = {}
predict_answer = {'images' : appended_list}
print(f'Predict_Answer Formulated')


# Assign Scene Type from Sample Answer to Submission

sample_answer_input = REPO_ROOT / 'exports/sample_answer.json' # Acquire Sample Answer path 

with open(sample_answer_input) as f: # Open Sample Answer Structure
    sample_answer = json.load(f)

sample_answer = sample_answer['images']


image_scenes = [] # Create list of images and associated 'scene_type'

for image in sample_answer:
    file_name = image.get('file_name') # GET each image's name
    scene_type = image.get('scene_type') # GET each image's scene_type

    image_scenes.append(  # Append to list
        {
            'filename':file_name, 
            'scene_type':scene_type
        }
    )


pd.json_normalize(image_scenes) #-- Potential redunant code --#

image_scenes_df = pd.DataFrame(image_scenes) # Transform Image_scenes list into DF

scene_map = image_scenes_df.set_index('filename')['scene_type'].to_dict() # Restructure image_scenes DF

submission = predict_answer

print('Append scene_types to predict_answer')
# Update each image in submission['images']
for image in submission['images']:
    filename = image['file_name']
    if image['scene_type'] == "Unknown" and filename in scene_map:
        image['scene_type'] = scene_map[filename]



print('Export Submission')
# Rewrite Submission JSON File
OUT_JSON.parent.mkdir(parents=True, exist_ok=True)
with open(OUT_JSON, "w") as f:
    json.dump(submission, f, indent=2)


print(f"Export Submission Complete \
      Saved As: 'Submission' \
      Saved At : {OUT_JSON}")
# Out:
# Get Meta Data
# Meta Data Items : [('10cm_evaluation_1.tif', {'file_name': '10cm_evaluation_1.tif', 'width': 1024, 'height': 1024, 'cm_resolution': '10', 'scene_type': 'Unknown'})]
# Meta Data Keys : [('10cm_evaluation_1.tif', {'file_name': '10cm_evaluation_1.tif', 'width': 1024, 'height': 1024, 'cm_resolution': '10', 'scene_type': 'Unknown'})]
# Append Meta Data To Images List
# images_sorted
# Get Annotations
# Annotations List Completed
# Appended_list Outputed
# Predict_Answer Formulated
# Append scene_types to predict_answer
# Export Submission
# Export Submission Complete       Saved As: 'Submission'       Saved At : C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\notebooks\exports\2025-11-02\submission.json

# %% [markdown]
# # Make Predictions on Training Data

# %%
# Import Packages
import ultralytics
from ultralytics import YOLO
import numpy as np
import time
import yaml
from pathlib import Path
import torch
import pandas as pd
from shutil import copy2

#-- Directories and Paths --#
REPO_ROOT = Path("..")      

DATA_CONFIG_PATH = REPO_ROOT / 'configurations' / 'model_data-seg.yaml'

#-- Model --#

# Load model parameters / overrides
with open(REPO_ROOT / 'configurations' / 'val_model_overrides.yaml', 'r') as f:
    overrides = yaml.safe_load(f)

# Override path in your dictionary
overrides['data'] = str(DATA_CONFIG_PATH)

# Assign Trained Model Weights
def resolve(p: str | Path) -> Path:
    p = Path(p)
    return p if p.is_absolute() else (REPO_ROOT / p)

weights_path = resolve(overrides.pop("weights"))

# Load Trained Model's Weights
model = YOLO(str(weights_path))  

# Predictions from the model
with torch.inference_mode():
    metrics = model.val(**overrides)


#-- Results --#

#--- Results Directory ---#
# where YOLO saved this run
out_dir = Path(metrics.save_dir)
out_dir.mkdir(parents=True, exist_ok=True)

#--- Precision & Recall Calculations ---#

# names -> {id: name}; confusion matrix includes a last row/col for "background"
names = [metrics.names[i] for i in range(len(metrics.names))]
cm = metrics.confusion_matrix.matrix.astype(np.int64)   # shape = (nc+1, nc+1) # cm = confusion_matrix
nc = len(names) # nc = name classes

# diagonal (exclude background) = TP
tp = np.diag(cm)[:nc]

# row sums (include background col) minus TP = FP for that predicted class
fp = cm[:nc, :].sum(axis=1) - tp

# column sums (include background row) minus TP = FN for that true class
fn = cm[:, :nc].sum(axis=0) - tp

precision = tp / (tp + fp + 1e-16)
recall    = tp / (tp + fn + 1e-16)
f1        = 2 * precision * recall / (precision + recall + 1e-16)

df = pd.DataFrame({
    "class": names, "TP": tp, "FP": fp, "FN": fn,
    "precision": precision, "recall": recall, "f1": f1
})
print(df)
# Output P&R Results
df.to_csv(out_dir / "P&R_results.csv", header=True,index=True)   
print(f"Saved df results metrics to {out_dir/'df_results.csv'}")


#-- Export Validation Results --#
# dataframe
validation_df = metrics.to_df()

# validation_df.to_csv(csv_path, header=True, index=True)
summary_df = pd.DataFrame([metrics.results_dict])  # <-- dict -> one-row DataFrame
summary_df.to_csv(out_dir / "summary_metrics_results.csv", index=False)
print(f"Saved metrics to {out_dir/'results.csv'}")




# choose task: 'seg' for masks, 'box' for boxes
task = 'seg' # Choosing specific 'task' type of 'segmentation' selects for metric associates
seg_metrics = getattr(metrics, task)

print(f"AP@0.75 ({task}): {seg_metrics.map75:.4f}")
print(f"AP@0.50 ({task}): {seg_metrics.map50:.4f}")
print(f"Classes  mAP@0.50:0.95 ({task}): {seg_metrics.map:.4f}")

# Per-class mAP (COCO mAP@0.50:0.95) if exposed
names = metrics.names if isinstance(metrics.names, (list, tuple)) else list(metrics.names.values())
if hasattr(seg_metrics, "maps") and seg_metrics.maps is not None:
    for i, name in enumerate(names):
        print(f"{name:>16}  mAP@0.50:0.95 = {seg_metrics.maps[i]:.4f}")


# Copy test_parameters into output folder
test_model_overrides = Path(REPO_ROOT / 'configurations/val_model_overrides.yaml')
copy2(test_model_overrides, metrics.save_dir / test_model_overrides.name )
try:
    print(f'"val_model_parameters" Copied to : {metrics.save_dir}')
except Exception:
    print('Error - Parameters Not Copied To Output')

# State output location
try:
    print("Output Metrics Saved to:", metrics.save_dir)
except Exception:
    print('Error - Location Not Printed')
# Out:
# Ultralytics 8.3.185  Python-3.11.14 torch-2.0.1+cu117 CUDA:0 (NVIDIA RTX A2000 12GB, 12281MiB)
# YOLO11m-seg summary (fused): 138 layers, 22,336,854 parameters, 0 gradients, 112.9 GFLOPs
# val: Fast image access  (ping: 0.40.1 ms, read: 196.518.9 MB/s, size: 3072.3 KB)
# val: Scanning C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\labels\val.cache... 30 images, 0 bac
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP
# requirements: Ultralytics requirement ['faster-coco-eval>=1.6.7'] not found, attempting AutoUpdate...
# Collecting faster-coco-eval>=1.6.7
#   Downloading faster_coco_eval-1.7.0-cp311-cp311-win_amd64.whl.metadata (9.1 kB)
# Requirement already satisfied: numpy in c:\users\hmanasi1\.conda\envs\gpu\lib\site-packages (from faster-coco-eval>=1.6.7) (1.26.4)
# Downloading faster_coco_eval-1.7.0-cp311-cp311-win_amd64.whl (319 kB)
# Installing collected packages: faster-coco-eval
# Successfully installed faster-coco-eval-1.7.0
#
# requirements: AutoUpdate success  6.9s
# WARNING requirements: Restart runtime or rerun command for updates to take effect
#
# WARNING Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP
# WARNING Limiting validation plots to first 50 items per image for speed...
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95)     Mask(P          R      mAP
#                    all         30       7960      0.577      0.256      0.416      0.242      0.591      0.257      0.425      0.202
#        individual_tree         30       7104      0.695      0.388      0.555      0.318      0.683      0.382      0.546      0.251
#         group_of_trees         26        856      0.459      0.123      0.276      0.166      0.498      0.133      0.305      0.152
# Speed: 4.5ms preprocess, 89.4ms inference, 0.0ms loss, 26.5ms postprocess per image
# Saving runs\segment\val_Yolo11m_canopy_adamW_\predictions.json...
# Results saved to runs\segment\val_Yolo11m_canopy_adamW_
#              class    TP    FP    FN  precision    recall        f1
# 0  individual_tree  2836  1131  4268   0.714898  0.399212  0.512330
# 1   group_of_trees   105   124   751   0.458515  0.122664  0.193548
# Saved df results metrics to runs\segment\val_Yolo11m_canopy_adamW_\df_results.csv
# Saved metrics to runs\segment\val_Yolo11m_canopy_adamW_\results.csv
# AP@0.75 (seg): 0.1661
# AP@0.50 (seg): 0.4253
# Classes  mAP@0.50:0.95 (seg): 0.2016
#  individual_tree  mAP@0.50:0.95 = 0.2514
#   group_of_trees  mAP@0.50:0.95 = 0.1518
# "val_model_parameters" Copied to : runs\segment\val_Yolo11m_canopy_adamW_
# Output Metrics Saved to: runs\segment\val_Yolo11m_canopy_adamW_

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from pathlib import Path

# ---------- Settings ----------
out_dir = Path("runs/segment/val_Yolo11m_canopy_adamW_")  # your metrics folder
sns.set(style="whitegrid")
plt.rcParams.update({'figure.autolayout': True})

# ---------- Load Metrics ----------
df = pd.read_csv(out_dir / "df_results.csv", index_col=0)

# Example per-class mAP (replace with your real values if loaded separately)
map_df = pd.DataFrame({
    "class": ["individual_tree", "group_of_trees"],
    "mAP50-95": [0.2514, 0.1518]
})

# ---------- 1. Confusion Matrix Heatmap (TP/FP/FN) ----------
cm_df = df.set_index("class")[["TP","FP","FN"]]

plt.figure(figsize=(8,6))
sns.heatmap(cm_df, annot=True, fmt="d", cmap="Blues")
plt.title("TP / FP / FN per Class")
plt.savefig(out_dir / "confusion_matrix.png")
plt.show()

# ---------- 2. Precision / Recall / F1 Bar Chart ----------
metrics_plot = df.set_index("class")[["precision","recall","f1"]]

metrics_plot.plot(kind='bar', figsize=(10,6))
plt.ylim(0,1)
plt.ylabel("Score")
plt.title("Per-Class Precision, Recall, F1")
plt.xticks(rotation=30)
plt.tight_layout()
plt.savefig(out_dir / "per_class_PRF.png")
plt.show()

# ---------- 3. Per-Class mAP Bar Chart ----------
plt.figure(figsize=(6,4))
sns.barplot(data=map_df, x="class", y="mAP50-95", palette="viridis")
plt.ylim(0,1)
plt.title("Per-Class mAP@0.50:0.95")
plt.ylabel("mAP")
plt.savefig(out_dir / "per_class_mAP.png")
plt.show()

# ---------- 4. Combined Precision vs mAP Chart ----------
combined_df = df.merge(map_df, on="class")
combined_df = combined_df.melt(id_vars="class", value_vars=["precision","mAP50-95"], 
                               var_name="Metric", value_name="Score")

plt.figure(figsize=(8,5))
sns.barplot(data=combined_df, x="class", y="Score", hue="Metric", palette="Set2")
plt.ylim(0,1)
plt.title("Precision vs mAP per Class")
plt.savefig(out_dir / "precision_vs_mAP.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[8], line 12
#       9 plt.rcParams.update({'figure.autolayout': True})
#      11 # ---------- Load Metrics ----------
# ---> 12 df = pd.read_csv(out_dir / "df_results.csv", index_col=0)
#      14 # Example per-class mAP (replace with your real values if loaded separately)
#      15 map_df = pd.DataFrame({
#      16     "class": ["individual_tree", "group_of_trees"],
#      17     "mAP50-95": [0.2514, 0.1518]
#      18 })
#
# File ~\.conda\envs\GPU\Lib\site-packages\pandas\io\parsers\readers.py:1026, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#    1013 kwds_defaults = _refine_defaults_read(
#    1014     dialect,
#    1015     delimiter,
#    (...)   1022     dtype_backend=dtype_backend,
#    1023 )
#    1024 kwds.update(kwds_defaults)
# -> 1026 return _read(filepath_or_buffer, kwds)
#
# File ~\.conda\envs\GPU\Lib\site-packages\pandas\io\parsers\readers.py:620, in _read(filepath_or_buffer, kwds)
#     617 _validate_names(kwds.get("names", None))
#     619 # Create the parser.
# --> 620 parser = TextFileReader(filepath_or_buffer, **kwds)
#     622 if chunksize or iterator:
#     623     return parser
#
# File ~\.conda\envs\GPU\Lib\site-packages\pandas\io\parsers\readers.py:1620, in TextFileReader.__init__(self, f, engine, **kwds)
#    1617     self.options["has_index_names"] = kwds["has_index_names"]
#    1619 self.handles: IOHandles | None = None
# -> 1620 self._engine = self._make_engine(f, self.engine)
#
# File ~\.conda\envs\GPU\Lib\site-packages\pandas\io\parsers\readers.py:1880, in TextFileReader._make_engine(self, f, engine)
#    1878     if "b" not in mode:
#    1879         mode += "b"
# -> 1880 self.handles = get_handle(
#    1881     f,
#    1882     mode,
#    1883     encoding=self.options.get("encoding", None),
#    1884     compression=self.options.get("compression", None),
#    1885     memory_map=self.options.get("memory_map", False),
#    1886     is_text=is_text,
#    1887     errors=self.options.get("encoding_errors", "strict"),
#    1888     storage_options=self.options.get("storage_options", None),
#    1889 )
#    1890 assert self.handles is not None
#    1891 f = self.handles.handle
#
# File ~\.conda\envs\GPU\Lib\site-packages\pandas\io\common.py:873, in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     868 elif isinstance(handle, str):
#     869     # Check whether the filename is to be opened in binary mode.
#     870     # Binary mode does not support 'encoding' and 'newline'.
#     871     if ioargs.encoding and "b" not in ioargs.mode:
#     872         # Encoding
# --> 873         handle = open(
#     874             handle,
#     875             ioargs.mode,
#     876             encoding=ioargs.encoding,
#     877             errors=errors,
#     878             newline="",
#     879         )
#     880     else:
#     881         # Binary mode
#     882         handle = open(handle, ioargs.mode)
#
# FileNotFoundError: [Errno 2] No such file or directory: 'runs\\segment\\val_Yolo11m_canopy_adamW_\\df_results.csv'

# %% [markdown]
# # Make Prediction On Evaluation Data

# %%
import ultralytics
from ultralytics import YOLO
import numpy as np
import time
import yaml
from pathlib import Path
import torch
from datetime import datetime

REPO_ROOT = Path("..")   

# Load model parameters / overrides YAML
with open(REPO_ROOT / 'configurations' / 'predict_model_overrides.yaml', 'r') as f: # Modify overrides where necessary
    overrides = yaml.safe_load(f)

# Make YAML Paths Absolute
for key in ("source", "project"):
    if key in overrides:
        overrides[key] = str((REPO_ROOT / overrides[key]).resolve())

# Load Trained Model Weights
def resolve(p: str | Path) -> Path:
    p = Path(p)
    return p if p.is_absolute() else (REPO_ROOT / p)

weights_path = resolve(overrides.pop("weights"))

# Model Naming
# optional: use the training run name from the weights path
train_run = weights_path.parents[1].name  # e.g., train_Yolov8s_canopy_832_...
run_name = f"predict_{train_run}"

# inject name (and project if you want a different subfolder)
overrides.setdefault("project", str(REPO_ROOT / "runs"))
overrides["name"] = run_name
# overrides["exist_ok"] = True  # set True to overwrite instead of auto-appending _2

# Load Trained Model's Weights
model = YOLO(str(weights_path))  

# Predictions from the model
with torch.inference_mode():
    predictions = model.predict(**overrides)

# State output location

# Stream = True
for last in predictions:
    pass
print("Saved to:", last.save_dir)

# Stream = False
# print("Outputs saved to:", predictions[0].save_dir)
# Out:
# image 1/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_1.tif: 1024x1024 58 individual_trees, 5 group_of_treess, 52.3ms
# image 2/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_10.tif: 1024x1024 142 individual_trees, 13 group_of_treess, 50.9ms
# image 3/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_11.tif: 1024x1024 36 individual_trees, 12 group_of_treess, 45.0ms
# image 4/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_12.tif: 1024x1024 36 individual_trees, 27 group_of_treess, 44.7ms
# image 5/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_13.tif: 1024x1024 165 individual_trees, 2 group_of_treess, 55.0ms
# image 6/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_14.tif: 1024x1024 107 individual_trees, 25 group_of_treess, 47.8ms
# image 7/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_15.tif: 1024x1024 108 individual_trees, 22 group_of_treess, 68.6ms
# image 8/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_16.tif: 1024x1024 119 individual_trees, 2 group_of_treess, 57.7ms
# image 9/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_17.tif: 1024x1024 118 individual_trees, 17 group_of_treess, 72.6ms
# image 10/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_18.tif: 1024x1024 144 individual_trees, 3 group_of_treess, 64.3ms
# image 11/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_19.tif: 1024x1024 191 individual_trees, 1 group_of_trees, 92.7ms
# image 12/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_2.tif: 1024x1024 65 individual_trees, 1 group_of_trees, 61.4ms
# image 13/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_20.tif: 1024x1024 167 individual_trees, 63.5ms
# image 14/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_21.tif: 1024x1024 147 individual_trees, 1 group_of_trees, 87.1ms
# image 15/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_22.tif: 1024x1024 152 individual_trees, 5 group_of_treess, 66.9ms
# image 16/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_23.tif: 1024x1024 79 individual_trees, 5 group_of_treess, 87.3ms
# image 17/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_24.tif: 1024x1024 148 individual_trees, 1 group_of_trees, 83.9ms
# image 18/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_25.tif: 1024x1024 141 individual_trees, 68.9ms
# image 19/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_26.tif: 1024x1024 36 individual_trees, 56.6ms
# image 20/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_27.tif: 1024x1024 300 individual_trees, 59.4ms
# image 21/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_28.tif: 1024x1024 184 individual_trees, 12 group_of_treess, 214.9ms
# image 22/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_29.tif: 1024x1024 86 individual_trees, 6 group_of_treess, 250.3ms
# image 23/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_3.tif: 1024x1024 11 individual_trees, 2 group_of_treess, 52.7ms
# image 24/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_30.tif: 1024x1024 200 individual_trees, 8 group_of_treess, 52.7ms
# image 25/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_31.tif: 1024x1024 137 individual_trees, 2 group_of_treess, 52.6ms
# image 26/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_32.tif: 1024x1024 290 individual_trees, 10 group_of_treess, 78.7ms
# image 27/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_33.tif: 1024x1024 100 individual_trees, 298.4ms
# image 28/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_34.tif: 1024x1024 228 individual_trees, 6 group_of_treess, 53.0ms
# image 29/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_35.tif: 1024x1024 58 individual_trees, 92.6ms
# image 30/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_36.tif: 1024x1024 98 individual_trees, 2 group_of_treess, 73.5ms
# image 31/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_37.tif: 1024x1024 102 individual_trees, 74.6ms
# image 32/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_38.tif: 1024x1024 300 individual_trees, 89.2ms
# image 33/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_4.tif: 1024x1024 81 individual_trees, 15 group_of_treess, 202.6ms
# image 34/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_5.tif: 1024x1024 14 individual_trees, 11 group_of_treess, 53.6ms
# image 35/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_6.tif: 1024x1024 18 individual_trees, 5 group_of_treess, 54.5ms
# image 36/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_7.tif: 1024x1024 300 individual_trees, 55.5ms
# image 37/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_8.tif: 1024x1024 23 individual_trees, 15 group_of_treess, 89.2ms
# image 38/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\10cm_evaluation_9.tif: 1024x1024 33 individual_trees, 6 group_of_treess, 77.6ms
# image 39/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_39.tif: 1024x1024 269 individual_trees, 31 group_of_treess, 69.9ms
# image 40/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_40.tif: 1024x1024 238 individual_trees, 26 group_of_treess, 128.7ms
# image 41/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_41.tif: 1024x1024 276 individual_trees, 24 group_of_treess, 223.4ms
# image 42/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_42.tif: 1024x1024 106 individual_trees, 106.1ms
# image 43/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_43.tif: 1024x1024 281 individual_trees, 19 group_of_treess, 122.9ms
# image 44/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_44.tif: 1024x1024 119 individual_trees, 1 group_of_trees, 328.3ms
# image 45/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_45.tif: 1024x1024 114 individual_trees, 8 group_of_treess, 52.6ms
# image 46/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_46.tif: 1024x1024 100 individual_trees, 79.0ms
# image 47/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_47.tif: 1024x1024 118 individual_trees, 4 group_of_treess, 96.1ms
# image 48/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_48.tif: 1024x1024 118 individual_trees, 4 group_of_treess, 68.1ms
# image 49/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_49.tif: 1024x1024 265 individual_trees, 35 group_of_treess, 91.7ms
# image 50/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_50.tif: 1024x1024 111 individual_trees, 12 group_of_treess, 240.9ms
# image 51/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_51.tif: 1024x1024 97 individual_trees, 8 group_of_treess, 55.4ms
# image 52/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_52.tif: 1024x1024 270 individual_trees, 30 group_of_treess, 70.8ms
# image 53/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_53.tif: 1024x1024 85 individual_trees, 28 group_of_treess, 132.1ms
# image 54/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_54.tif: 1024x1024 94 individual_trees, 20 group_of_treess, 112.2ms
# image 55/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_55.tif: 1024x1024 121 individual_trees, 11 group_of_treess, 79.9ms
# image 56/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_56.tif: 1024x1024 271 individual_trees, 29 group_of_treess, 73.3ms
# image 57/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_57.tif: 1024x1024 96 individual_trees, 268.4ms
# image 58/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_58.tif: 1024x1024 92 individual_trees, 56.9ms
# image 59/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_59.tif: 1024x1024 115 individual_trees, 74.2ms
# image 60/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_60.tif: 1024x1024 85 individual_trees, 1 group_of_trees, 64.2ms
# image 61/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_61.tif: 1024x1024 68 individual_trees, 12 group_of_treess, 57.4ms
# image 62/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_62.tif: 1024x1024 109 individual_trees, 59.9ms
# image 63/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_63.tif: 1024x1024 263 individual_trees, 37 group_of_treess, 69.0ms
# image 64/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_64.tif: 1024x1024 46 individual_trees, 21 group_of_treess, 253.8ms
# image 65/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_65.tif: 1024x1024 115 individual_trees, 52.7ms
# image 66/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_66.tif: 1024x1024 67 individual_trees, 10 group_of_treess, 52.6ms
# image 67/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_67.tif: 1024x1024 257 individual_trees, 43 group_of_treess, 65.9ms
# image 68/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_68.tif: 1024x1024 89 individual_trees, 123.1ms
# image 69/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_69.tif: 1024x1024 110 individual_trees, 1 group_of_trees, 106.0ms
# image 70/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_70.tif: 1024x1024 278 individual_trees, 22 group_of_treess, 74.8ms
# image 71/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_71.tif: 1024x1024 97 individual_trees, 126.9ms
# image 72/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_72.tif: 1024x1024 282 individual_trees, 18 group_of_treess, 91.1ms
# image 73/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_73.tif: 1024x1024 276 individual_trees, 24 group_of_treess, 266.3ms
# image 74/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_74.tif: 1024x1024 86 individual_trees, 13 group_of_treess, 253.1ms
# image 75/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\20cm_evaluation_75.tif: 1024x1024 93 individual_trees, 10 group_of_treess, 52.6ms
# image 76/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_100.tif: 1024x1024 242 individual_trees, 20 group_of_treess, 52.5ms
# image 77/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_76.tif: 1024x1024 56 individual_trees, 9 group_of_treess, 51.0ms
# image 78/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_77.tif: 1024x1024 155 individual_trees, 32 group_of_treess, 67.9ms
# image 79/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_78.tif: 1024x1024 231 individual_trees, 60 group_of_treess, 65.8ms
# image 80/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_79.tif: 1024x1024 279 individual_trees, 21 group_of_treess, 239.5ms
# image 81/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_80.tif: 1024x1024 248 individual_trees, 51 group_of_treess, 112.6ms
# image 82/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_81.tif: 1024x1024 175 individual_trees, 56 group_of_treess, 84.2ms
# image 83/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_82.tif: 1024x1024 117 individual_trees, 27 group_of_treess, 64.4ms
# image 84/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_83.tif: 1024x1024 223 individual_trees, 30 group_of_treess, 80.8ms
# image 85/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_84.tif: 1024x1024 131 individual_trees, 33 group_of_treess, 127.5ms
# image 86/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_85.tif: 1024x1024 70 individual_trees, 15 group_of_treess, 54.1ms
# image 87/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_86.tif: 1024x1024 221 individual_trees, 22 group_of_treess, 69.0ms
# image 88/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_87.tif: 1024x1024 238 individual_trees, 59 group_of_treess, 59.9ms
# image 89/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_88.tif: 1024x1024 280 individual_trees, 20 group_of_treess, 101.6ms
# image 90/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_89.tif: 1024x1024 265 individual_trees, 35 group_of_treess, 256.4ms
# image 91/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_90.tif: 1024x1024 276 individual_trees, 24 group_of_treess, 107.3ms
# image 92/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_91.tif: 1024x1024 265 individual_trees, 35 group_of_treess, 113.9ms
# image 93/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_92.tif: 1024x1024 262 individual_trees, 38 group_of_treess, 270.0ms
# image 94/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_93.tif: 1024x1024 268 individual_trees, 32 group_of_treess, 109.1ms
# image 95/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_94.tif: 1024x1024 281 individual_trees, 19 group_of_treess, 118.7ms
# image 96/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_95.tif: 1024x1024 177 individual_trees, 45 group_of_treess, 265.4ms
# image 97/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_96.tif: 1024x1024 171 individual_trees, 10 group_of_treess, 52.5ms
# image 98/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_97.tif: 1024x1024 77 individual_trees, 5 group_of_treess, 52.3ms
# image 99/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_98.tif: 1024x1024 264 individual_trees, 36 group_of_treess, 70.3ms
# image 100/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\40cm_evaluation_99.tif: 1024x1024 291 individual_trees, 9 group_of_treess, 112.7ms
# image 101/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_101.tif: 1024x1024 235 individual_trees, 60 group_of_treess, 193.8ms
# image 102/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_102.tif: 1024x1024 199 individual_trees, 99 group_of_treess, 118.3ms
# image 103/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_103.tif: 1024x1024 169 individual_trees, 131 group_of_treess, 262.8ms
# image 104/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_104.tif: 1024x1024 241 individual_trees, 58 group_of_treess, 113.1ms
# image 105/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_105.tif: 1024x1024 179 individual_trees, 119 group_of_treess, 237.7ms
# image 106/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_106.tif: 1024x1024 176 individual_trees, 122 group_of_treess, 108.6ms
# image 107/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_107.tif: 1024x1024 282 individual_trees, 16 group_of_treess, 122.1ms
# image 108/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_108.tif: 1024x1024 233 individual_trees, 66 group_of_treess, 115.3ms
# image 109/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_109.tif: 1024x1024 274 individual_trees, 26 group_of_treess, 212.9ms
# image 110/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_110.tif: 1024x1024 283 individual_trees, 14 group_of_treess, 115.5ms
# image 111/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_111.tif: 1024x1024 230 individual_trees, 70 group_of_treess, 316.6ms
# image 112/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_112.tif: 1024x1024 263 individual_trees, 37 group_of_treess, 116.3ms
# image 113/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_113.tif: 1024x1024 265 individual_trees, 35 group_of_treess, 110.2ms
# image 114/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_114.tif: 1024x1024 274 individual_trees, 25 group_of_treess, 283.7ms
# image 115/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_115.tif: 1024x1024 125 individual_trees, 23 group_of_treess, 218.7ms
# image 116/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_116.tif: 1024x1024 197 individual_trees, 103 group_of_treess, 55.3ms
# image 117/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_117.tif: 1024x1024 182 individual_trees, 118 group_of_treess, 300.6ms
# image 118/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_118.tif: 1024x1024 148 individual_trees, 152 group_of_treess, 295.5ms
# image 119/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_119.tif: 1024x1024 242 individual_trees, 58 group_of_treess, 178.4ms
# image 120/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_120.tif: 1024x1024 282 individual_trees, 18 group_of_treess, 190.0ms
# image 121/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_121.tif: 1024x1024 257 individual_trees, 42 group_of_treess, 110.4ms
# image 122/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_122.tif: 1024x1024 206 individual_trees, 93 group_of_treess, 316.7ms
# image 123/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_123.tif: 1024x1024 286 individual_trees, 14 group_of_treess, 300.4ms
# image 124/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_124.tif: 1024x1024 262 individual_trees, 38 group_of_treess, 231.4ms
# image 125/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\60cm_evaluation_125.tif: 1024x1024 292 individual_trees, 8 group_of_treess, 108.8ms
# image 126/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_126.tif: 1024x1024 277 individual_trees, 23 group_of_treess, 251.6ms
# image 127/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_127.tif: 1024x1024 287 individual_trees, 13 group_of_treess, 112.5ms
# image 128/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_128.tif: 1024x1024 274 individual_trees, 26 group_of_treess, 124.5ms
# image 129/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_129.tif: 1024x1024 267 individual_trees, 33 group_of_treess, 320.8ms
# image 130/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_130.tif: 1024x1024 282 individual_trees, 18 group_of_treess, 111.1ms
# image 131/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_131.tif: 1024x1024 275 individual_trees, 25 group_of_treess, 257.3ms
# image 132/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_132.tif: 1024x1024 288 individual_trees, 12 group_of_treess, 231.8ms
# image 133/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_133.tif: 1024x1024 254 individual_trees, 45 group_of_treess, 107.3ms
# image 134/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_134.tif: 1024x1024 237 individual_trees, 63 group_of_treess, 312.0ms
# image 135/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_135.tif: 1024x1024 265 individual_trees, 35 group_of_treess, 305.9ms
# image 136/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_136.tif: 1024x1024 266 individual_trees, 34 group_of_treess, 302.6ms
# image 137/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_137.tif: 1024x1024 240 individual_trees, 60 group_of_treess, 90.2ms
# image 138/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_138.tif: 1024x1024 238 individual_trees, 62 group_of_treess, 126.8ms
# image 139/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_139.tif: 1024x1024 282 individual_trees, 18 group_of_treess, 224.2ms
# image 140/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_140.tif: 1024x1024 280 individual_trees, 19 group_of_treess, 121.7ms
# image 141/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_141.tif: 1024x1024 273 individual_trees, 26 group_of_treess, 215.3ms
# image 142/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_142.tif: 1024x1024 281 individual_trees, 17 group_of_treess, 117.7ms
# image 143/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_143.tif: 1024x1024 237 individual_trees, 63 group_of_treess, 195.3ms
# image 144/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_144.tif: 1024x1024 260 individual_trees, 40 group_of_treess, 270.6ms
# image 145/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_145.tif: 1024x1024 274 individual_trees, 25 group_of_treess, 110.4ms
# image 146/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_146.tif: 1024x1024 249 individual_trees, 51 group_of_treess, 148.9ms
# image 147/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_147.tif: 1024x1024 248 individual_trees, 52 group_of_treess, 197.5ms
# image 148/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_148.tif: 1024x1024 268 individual_trees, 32 group_of_treess, 113.0ms
# image 149/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_149.tif: 1024x1024 264 individual_trees, 36 group_of_treess, 216.0ms
# image 150/150 C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\data\processed\images\predict\80cm_evaluation_150.tif: 1024x1024 246 individual_trees, 54 group_of_treess, 112.5ms
# Speed: 11.5ms preprocess, 131.3ms inference, 95.9ms postprocess per image at shape (1, 3, 1024, 1024)
# Results saved to C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\runs\segment\predict_train_Yolo11m_canopy_adamW_
# 150 labels saved to C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\runs\segment\predict_train_Yolo11m_canopy_adamW_\labels
# Saved to: C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\runs\segment\predict_train_Yolo11m_canopy_adamW_

# %%
# Packages
from pathlib import Path
import pandas as pd
import numpy as np
import json
from PIL import Image
import pandas as pd
from datetime import datetime

# Create paths
REPO_ROOT = Path.cwd()

# Prediction Annotations
labels = "../runs/segment/predict_train_Yolo11m_canopy_adamW_\labels" # Modify Prediction Txt annotations where necessary
IMGS = '../data/processed/images/predict'
OUT_JSON = REPO_ROOT / 'exports/med/submission.json'



#---Define Functions---#

# Image Metadata
def get_meta(IMGS):

    meta_data = {}
    scene_type_default = "Unknown"
    IMGS = Path(IMGS)

    if IMGS.exists():

        for p in Path(IMGS).iterdir():
            if p.suffix.lower() not in {".tif"}: # All images .tif
                continue
            file_name = p.name
            cm_resolution = str(file_name[0:2])

            with Image.open(p) as image: # Pillow / Pill package
                width, height = image.size

            meta_data[file_name] = {
                'file_name' : file_name,
                "width" : width,
                'height' : height,
                "cm_resolution" : cm_resolution,
                "scene_type" : scene_type_default

            }
    else:
      print('Error - IMGs Not Exist')
    return meta_data

# Get Annotations
def get_annotations(LABELS):
    annotations = []

    for txt_file in sorted(Path(LABELS).iterdir()):
        
        if txt_file.is_file() and txt_file.suffix.lower() == ".txt":
            image_name = txt_file.name

            with open(txt_file, 'r') as file:
                for line in file:

                    # 1. Split the line into tokens
                    tokens = line.strip().split()

                    # 2. Convert tokens into usable pieces
                    class_id = int(tokens[0])                    # first token
                    *coords, confidence_level = map(float, tokens[1:])  
                    # all middle tokens are coords, last one is confidence
                    

                    # 3. Group coords into pairs (x,y)
                    segmentation = [
                        (coords[i], coords[i+1])
                        for i in range(0, len(coords), 2)
                    ]

                    # 4. Save everything into dict
                    annotations.append({
                        "image": image_name,
                        "class": class_id,
                        "confidence_level": confidence_level,
                        "segmentation": segmentation
                    })

    return annotations


# Denormalise segmentations to pixels

def denorm_segmentation(seg, width, height, *, flatten=True, round_int=True):
    """
    seg: list of (x,y) pairs in [0,1]
    returns: flat pixel list [x1,y1,x2,y2,...] (default) or list of pairs
    """
    # If seg is already flat [x1,y1,...], turn into pairs
    if seg and not isinstance(seg[0], (list, tuple)):
        it = iter(seg)
        seg_pairs = list(zip(it, it))
    else:
        seg_pairs = seg

    out = []
    for x, y in seg_pairs:
        X = max(0.0, min(width  - 1, x * width))
        Y = max(0.0, min(height - 1, y * height))
        if round_int:
            X = int(round(X))
            Y = int(round(Y))
        if flatten:
            out.extend([X, Y])
        else:
            out.append((X, Y))
    return out


# Append annotations to images

def append_imgs_annotations(img_list, annot_list):
    # ensure each image has an annotations list
    for img in img_list:
        if "annotations" not in img or img["annotations"] is None:
            img["annotations"] = []

    for image in img_list:
        w, h = image["width"], image["height"]
        fname = image["file_name"]

        # all annots for this image
        matched = (a for a in annot_list if a["image"] == fname)

        for a in matched:
            seg_px = denorm_segmentation(a["segmentation"], w, h, flatten=True, round_int=True) # Denormalise Segemetation to Pixels

            image["annotations"].append({
                "class": a["class"],
                "confidence_score": float(a["confidence_level"]),  # or keep as formatted string if you prefer
                "segmentation": seg_px
            })

    return img_list


# class id
ID_to_Name = {
    0 : 'individual_tree',
    1 : 'group_of_trees'
}



#--Procedure--#
print('Get Meta Data')
meta = get_meta(IMGS) # Retrieve Meta Data
meta_2items = list(meta.items())[:1]
meta_2keys = list(meta)[:1]

print(f'Meta Data Items : {meta_2items}')

print(f'Meta Data Keys : {meta_2items}')


images = [] # Produce Images list

print('Append Meta Data To Images List')
for m in meta.values(): # Append Meta Data to Images List
    images.append({
        'file_name' : m['file_name'],
        'width' : m['width'],
        'height' : m['height'],
        'cm_resolution' : m['cm_resolution'],
        'scene_type' : m['scene_type'],
        'annotations' : []
    })
    

images_sorted = sorted(images, key=lambda x: x['file_name']) # Sort Images
print(f'images_sorted ')
    
print('Get Annotations')
annotations_list = get_annotations(labels) # Retrieve Annotations & Denormalise Segmentations to Pixels

for annot in annotations_list: # Clean Annotations
    # .txt suffix -> .tif
    annot['image'] = annot['image'][:-4] + '.tif'

    # map class id -> name
    annot['class'] = ID_to_Name.get(annot['class'], 'Unknown')

    # convert confidence_level -> percentage string
    annot['confidence_level'] = f"{annot['confidence_level']:.2f}"

if annotations_list and len(annotations_list[0]) > 0:
    print('Annotations List Completed')

appended_list = append_imgs_annotations(images_sorted, annotations_list) # Append Annotations to Images

print(f'Appended_list Outputed ')

predict_answer = {}
predict_answer = {'images' : appended_list}
print(f'Predict_Answer Formulated')


# Assign Scene Type from Sample Answer to Submission

sample_answer_input = REPO_ROOT / 'exports/sample_answer.json' # Acquire Sample Answer path 

with open(sample_answer_input) as f: # Open Sample Answer Structure
    sample_answer = json.load(f)

sample_answer = sample_answer['images']


image_scenes = [] # Create list of images and associated 'scene_type'

for image in sample_answer:
    file_name = image.get('file_name') # GET each image's name
    scene_type = image.get('scene_type') # GET each image's scene_type

    image_scenes.append(  # Append to list
        {
            'filename':file_name, 
            'scene_type':scene_type
        }
    )


pd.json_normalize(image_scenes) #-- Potential redunant code --#

image_scenes_df = pd.DataFrame(image_scenes) # Transform Image_scenes list into DF

scene_map = image_scenes_df.set_index('filename')['scene_type'].to_dict() # Restructure image_scenes DF

submission = predict_answer

print('Append scene_types to predict_answer')
# Update each image in submission['images']
for image in submission['images']:
    filename = image['file_name']
    if image['scene_type'] == "Unknown" and filename in scene_map:
        image['scene_type'] = scene_map[filename]



print('Export Submission')
# Rewrite Submission JSON File
OUT_JSON.parent.mkdir(parents=True, exist_ok=True)
with open(OUT_JSON, "w") as f:
    json.dump(submission, f, indent=2)


print(f"Export Submission Complete \
      Saved As: 'Submission' \
      Saved At : {OUT_JSON}")
# Out:
# Get Meta Data
# Meta Data Items : [('10cm_evaluation_1.tif', {'file_name': '10cm_evaluation_1.tif', 'width': 1024, 'height': 1024, 'cm_resolution': '10', 'scene_type': 'Unknown'})]
# Meta Data Keys : [('10cm_evaluation_1.tif', {'file_name': '10cm_evaluation_1.tif', 'width': 1024, 'height': 1024, 'cm_resolution': '10', 'scene_type': 'Unknown'})]
# Append Meta Data To Images List
# images_sorted
# Get Annotations
# Annotations List Completed
# Appended_list Outputed
# Predict_Answer Formulated
# Append scene_types to predict_answer
# Export Submission
# Export Submission Complete       Saved As: 'Submission'       Saved At : C:\Users\hmanasi1\Documents\ADML\solafune_tree_canopy\notebooks\exports\med\submission.json
